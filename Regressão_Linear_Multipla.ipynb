# %% [markdown]
# <a href="https://colab.research.google.com/github/Winicius-dos-Passos/Regressao-linear-multipla/blob/main/Regress%C3%A3o_Linear_Multipla.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importação das bibliotecas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import statsmodels.formula.api as sm

# %%
# Carregamento da base de dados e exclusão da primeira coluna
df = pd.read_csv('mt_cars.csv')
display(df)
# Out:
#              Unnamed: 0   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %%
df.drop(columns=['Unnamed: 0'], inplace=True)
df.shape
# Out:
# (32, 11)

# %%
# Criação de X e Y: Variável independente e variável dependente
# Cálculo da correlação entre X e Y
X = df.iloc[:, 2].values # coluna disp
y = df.iloc[:, 0].values # coluna mpg
correlacao = np.corrcoef(X, y)
print(correlacao)
# Out:
# [[ 1.         -0.84755138]
#  [-0.84755138  1.        ]]

# %%
# Mudança de formato de X para o formato de matriz
X = X.reshape(-1, 1)

# %%
# Criação do modelo, treinamento, visualização dos coeficientes e do score do modelo
modelo = LinearRegression()
modelo.fit(X, y)
# Out:
# LinearRegression()

# %%
# Inclinação
modelo.coef_
# Out:
# array([-0.04121512])

# %%
# Interceptação
modelo.intercept_
# Out:
# np.float64(29.599854756163946)

# %%
# Coeficiente de determinação
modelo.score(X, y)
# Out:
# 0.7183433404897299

# %%
# Geração das previsões
previsoes = modelo.predict(X)
previsoes
# Out:
# array([23.00543556, 23.00543556, 25.1486218 , 18.96635381, 14.76241157,
#        20.32645276, 14.76241157, 23.55359666, 23.79676587, 22.69220065,
#        22.69220065, 18.23272467, 18.23272467, 18.23272467, 10.14631813,
#        10.64089957, 11.46520197, 26.35622482, 26.47987017, 26.66945973,
#        24.64991885, 16.49344661, 17.07045829, 15.17456277, 13.11380677,
#        26.34386028, 24.64167582, 25.68029685, 15.13334765, 23.62366236,
#        17.19410365, 24.61282524])

# %%
# Criação do modelo, utilizando a biblioteca statsmodel
# Podemos ver r ajustado r2
modelo_ajustado = sm.ols(formula= 'mpg ~ disp', data=df)
modelo_treinado = modelo_ajustado.fit()
modelo_treinado.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    mpg   R-squared:                       0.718
# Model:                            OLS   Adj. R-squared:                  0.709
# Method:                 Least Squares   F-statistic:                     76.51
# Date:                Sun, 05 Apr 2026   Prob (F-statistic):           9.38e-10
# Time:                        20:53:24   Log-Likelihood:                -82.105
# No. Observations:                  32   AIC:                             168.2
# Df Residuals:                      30   BIC:                             171.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     29.5999      1.230     24.070      0.000      27.088      32.111
# ...

# %%
# Plotar o gráfico
plt.scatter(X, y)
plt.plot(X, previsoes, color='red')
plt.show()

# %%
modelo.predict([[360]])
# Out:
# array([14.76241157])

# %%
# Criação de novas variáveis X1 e Y1 e novo modelo para comparação com o anterior
# 3 variáveis depedentes para prever mpg: cyl->disp->hp
X1 = df.iloc[:, 1:4].values
X1
# Out:
# array([[  6. , 160. , 110. ],
#        [  6. , 160. , 110. ],
#        [  4. , 108. ,  93. ],
#        [  6. , 258. , 110. ],
#        [  8. , 360. , 175. ],
#        [  6. , 225. , 105. ],
#        [  8. , 360. , 245. ],
#        [  4. , 146.7,  62. ],
#        [  4. , 140.8,  95. ],
#        [  6. , 167.6, 123. ],
#        [  6. , 167.6, 123. ],
#        [  8. , 275.8, 180. ],
#        [  8. , 275.8, 180. ],
#        [  8. , 275.8, 180. ],
#        [  8. , 472. , 205. ],
#        [  8. , 460. , 215. ],
#        [  8. , 440. , 230. ],
#        [  4. ,  78.7,  66. ],
#        [  4. ,  75.7,  52. ],
#        [  4. ,  71.1,  65. ],
#        [  4. , 120.1,  97. ],
#        [  8. , 318. , 150. ],
#        [  8. , 304. , 150. ],
#        [  8. , 350. , 245. ],
#        [  8. , 400. , 175. ],
#        [  4. ,  79. ,  66. ],
#        [  4. , 120.3,  91. ],
#        [  4. ,  95.1, 113. ],
#        [  8. , 351. , 264. ],
#        [  6. , 145. , 175. ],
#        [  8. , 301. , 335. ],
# ...

# %%
y1 = df.iloc[:, 0].values
modelo2 = LinearRegression()
modelo2.fit(X1, y1)
# Coeficiente de determinação
modelo2.score(X1, y1)
# Out:
# 0.7678877440928638

# %%
# Criação do modelo ajustado com mais atributos (regressão linear múltipla)
# Usando stats model
modelo_ajustado2 = sm.ols(formula= 'mpg ~ cyl + disp + hp', data=df)
modelo_treinado2 = modelo_ajustado2.fit()
modelo_treinado2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    mpg   R-squared:                       0.768
# Model:                            OLS   Adj. R-squared:                  0.743
# Method:                 Least Squares   F-statistic:                     30.88
# Date:                Sun, 05 Apr 2026   Prob (F-statistic):           5.05e-09
# Time:                        20:53:24   Log-Likelihood:                -79.009
# No. Observations:                  32   AIC:                             166.0
# Df Residuals:                      28   BIC:                             171.9
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     34.1849      2.591     13.195      0.000      28.878      39.492
# ...

# %%
# Previsão de um novo registro
novo = np.array([4, 200, 100])
novo = novo.reshape(1, -1)
modelo2.predict(novo)
# Out:
# array([24.03968887])
